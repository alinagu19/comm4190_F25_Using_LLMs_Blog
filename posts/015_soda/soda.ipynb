# %% [raw]
# ---
# title: "What Soda Does Chat-GPT Think Is My Spirit Animal"
# description: "Is there a soda out there that represents me?"
# author: "Alina"
# date: "11/19/2025"
# categories:
#   - LLMs
#   - Soda
#   - Spirit Animal
# ---

# %% [markdown]
# ### What soda does Chat-GPT5 think represents me the best?

# %% [markdown]
# Inspired by our in-class Pepsi and Coke debate, I thought I'd go a bit further. As a strong pepsi supporter, is there another soda out there that represents me as a person?

# %% [markdown]
# ![](sodas.png)

# %% [markdown]
# #### Prompt
# > Based on my past chats, what soda (out of any types that ever existed) would be my spirit animal?

# %% [markdown]
# #### Response
#
# >Based on your past chats, your *spirit soda* would 100% be **Mountain Dew Code Red** — and here’s why:
# >
# >### 🥤 Why Code Red Fits You
# >
# >**1. High-energy problem solving**
# >
# >You jump between debugging Python errors, PCA interpretation, equations, and faucet part identification like it’s nothing. Code Red is the soda equivalent of “let’s do this at 120% intensity.”
# >
# >**2. Creative + analytical combo**
# >
# >You don’t just troubleshoot code—you also ask about Funko Pop edits, MBTI, and spirit-animal sodas.
# Code Red is chaotic but also strangely focused. So are your chats.
# >
# >**3. Persistent curiosity**
# >
# >You revisit concepts (PCA, plotting, dictionaries, correlations) and keep drilling until something *clicks*.
# That’s a very Code Red “I will brute-force reality until it complies” vibe.
# >
# >**4. Slightly chaotic but extremely effective**
# >
# >Your questions often jump domains quickly—from statistics → plumbing → art → psychology.
# That’s basically the emotional arc of someone who drank Code Red at 11 PM and is now reorganizing their life.
# >
# >---
# >
# >### 🥤 Runner-up sodas
# >
# >* **Dr Pepper** — for multi-flavor complexity and your broad range of topics
# >
# >* **Sprite Cranberry** — seasonal, bold, unexpectedly iconic
# >
# >* **Vault** (discontinued) — because you sometimes go *full technical deep-dive mode* and resurrect old knowledge
#
# >---

# %% [markdown]
# #### Prompt
# > Generate an image of my funko pop with this representation

# %% [markdown]
# #### Response

# %% [markdown]
# ![](sodas2.png)

# %% [markdown]
# ### My Thoughts

# %% [markdown]
# Quite the interesting choice made by the LLM, but I can't say it's wrong (based on my past chats and prompts). Something that got noted twice was how "chaotic" I can be, which does make sense given the wide array of topics I choose to ask Chat-GPT about. I've never had Mountain Dew Code Red personally, but it does look like battery acid and diabetes in a bottle...so based on Chat-GPT's description of my inquiry history, I'd say it's quite accurate. I also thought it was cool how the LLM offered alternative sodas without me having to prompt it further for them.
#
# The image generation portion is also quite entertaining. Even though it's a bit simplistic and unoriginal, I thought my representative action figure from a previous blog post holding the can of Mountain Dew was quite funny. Some points off for the incorrect Mountain Dew logo in the background, but, other than that, it's still pretty accurate. 8.5/10.
