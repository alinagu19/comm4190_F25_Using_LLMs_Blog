# %% [raw]
# ---
# title: "How Well Can An LLM Teach Me To Play An Instrument: Part 1"
# author: "Alina"
# date: "11/25/2025"
# categories:
#   - LLMs
#   - Teach
#   - Instrument
# ---

# %% [markdown]
# ## How Well Can An LLM Teach Me To Play an Instrument - Part 1

# %% [markdown]
# I am going to ask ChatGPT (chatgpt-4o-latest) how to play an instrument. To test this first, I'll be asking the LLM to teach me about an instrument I already know how the play, the ukulele. In Part 2, I'll tr to use it to learn to play an instrument I've never even touched before!

# %% [markdown]
# ![](ukulele.jpg)

# %% [markdown]
# ## Prompt

# %% [markdown]
# #### USER
#
# Can you help me learn how to play the ukulele. I am new to string instruments. How do I tune it? I want to learn the most common chords and where to put my fingers. What are some good beginner songs? How do you strum a ukulele?

# %% [markdown]
# ## Response

# %% [markdown]
# #### ASSISTANT
# Absolutely! I'd be happy to help you get started with the ukulele — it's a fun and beginner-friendly instrument, perfect for people new to string instruments. Let's go step-by-step:
#
# ---
#
# #### 🎵 1. TUNING YOUR UKULELE
#
# The most common ukulele tuning (for a soprano, concert, or tenor ukulele) is **G–C–E–A** from top string (closest to your face) to bottom string (closest to the floor) when holding it.
#
# - The 4 strings are:
#   - **G** (4th string)
#   - **C** (3rd string)
#   - **E** (2nd string)
#   - **A** (1st string)
#
# ##### 🔧 How to tune it:
# - **Use a clip-on tuner** (highly recommended for beginners).
# - Make sure you're in **standard tuning (GCEA)**.
# - Each string should be tuned to its correct note. Pluck the string and adjust the tuning peg until the tuner shows it's in tune.
# - Most ukuleles use **reentrant tuning** (G is higher than C), but that's totally normal!
#
# ---
#
# #### 🎶 2. BASIC CHORDS TO LEARN FIRST
#
# Here are the most common ukulele chords for beginners. Use the tips of your fingers, and press the string down behind (just before) the fret:
#
# ##### 🌟 Must-Know Beginner Chords:
# - **C Major** (C): 3rd finger on the 3rd fret of the A string (bottom string).
# - **A Minor** (Am): 2nd finger on the 2nd fret of the G string (top string).
# - **F Major** (F): 1st finger on 1st fret of E string, 2nd finger on 2nd fret of G.
# - **G Major** (G): 1st finger on 2nd fret C string, 2nd finger on 2nd fret A string, 3rd finger on 3rd fret E string.
# - **D Minor** (Dm): Similar to F, but 3rd finger on 2nd fret of C string.
# - **E Minor** (Em): 1st finger 2nd fret A string, 2nd finger 3rd fret E, 3rd finger 4th fret C.
#
# 🔍 Try searching for chord charts online or using a free mobile app like Yousician, Ukulele Tabs, or Fender Play.
#
# ---
#
# #### 🎸 3. HOW TO STRUM A UKULELE
#
# ##### Basic Strumming Technique:
# - Use the **nail side of your index finger or thumb** to strum down, and the **pad of your finger or nail** to strum up.
# - Keep your strumming hand relaxed and the motion should come from your wrist, not your elbow.
#
# ##### Simple Strumming Patterns:
# - 🫰 **Down-down-down-down** (D D D D)
# - ➡️ **Down-up-down-up** (D U D U)
# - 🎵 **Down-down-up-up-down-up** (D D U U D U) — very common pattern.
#
# Practice each chord with a slow and even strum before trying patterns.
#
# ---
#
# #### 🎤 4. EASY SONGS TO START WITH
#
# Here are some songs with simple chord progressions (only 2–4 chords):
#
# ##### 🎸 One-Chord Song:
# - “Row, Row, Row Your Boat” — C
#
# ##### 🎵 Two-Chord Songs:
# - "He's Got the Whole World in His Hands" — C and G7
# - "Horse with No Name" (slightly altered) — Em and D6
#
# ##### 🎶 Three or Four-Chord Songs:
# - **"You Are My Sunshine"** — C, G, F
# - **"Riptide" by Vance Joy** — Am, G, C (plus F in chorus)
# - **"I'm Yours" by Jason Mraz** — C, G, Am, F
# - **"Let It Be" by The Beatles** — C, G, Am, F
#
# Most pop songs can be played with just C, G, Am, and F!
#
# ---
#
# #### 📘 TIPS FOR BEGINNERS
#
# - Practice changing between chords slowly and cleanly.
# - Don’t worry about speed — clean sound comes first.
# - Tune your ukulele every time you practice!
# - Build finger strength and muscle memory — 10–15 minutes a day is enough to make progress.
# - Look up ukulele playalong videos on YouTube to practice with music (try "The Ukulele Teacher" channel or "Cynthia Lin").
#
# ---
#
# Would you like printable chord charts, diagrams of finger positions, or a step-by-step lesson plan? I’d be happy to help you structure your learning! 😊

# %% [markdown]
# ## My Thoughts

# %% [markdown]
# Honestly this is not bad at all because this is probably how I'd introduce playing the ukulele to a brand new player. I will say I led the LLM a bit with my questions, but I think those are still genuine questions a completely beginner player would ask. The must-know beginner chords are spot on and so are the strumming patterns. The LLM also suggested a 4-week long lesson plan and, in my opinion, it's completely feasible and at a really good pace. However, I still likely would not recommend this LLM-centric method to someone who really wishes to learn how to play. Visual learning is probably the best way, but I may be a bit biased since that was the way I learned. Since I'm curious to see if truly learning solely from an LLM is possible, I will be trying it with an instrument I've never touched before, a harmonica.
